# %% [markdown]
# <h1>Table of Contents 💜<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Obteniendo-el-dataset" data-toc-modified-id="Obteniendo-el-dataset-1">Obteniendo el dataset</a></span></li><li><span><a href="#Separando-las-columnas-en-variables" data-toc-modified-id="Separando-las-columnas-en-variables-2">Separando las columnas en variables</a></span></li><li><span><a href="#Dividimos-los-datos-de-entrenamiento-y-de-testeo" data-toc-modified-id="Dividimos-los-datos-de-entrenamiento-y-de-testeo-3">Dividimos los datos de entrenamiento y de testeo</a></span></li><li><span><a href="#Llamamos-al-modelo" data-toc-modified-id="Llamamos-al-modelo-4">Llamamos al modelo</a></span></li><li><span><a href="#Entrenamos" data-toc-modified-id="Entrenamos-5">Entrenamos</a></span></li><li><span><a href="#Visualizamos" data-toc-modified-id="Visualizamos-6">Visualizamos</a></span></li><li><span><a href="#Revisando-el-score-del-entrenamiento-y-de-las-predicciones." data-toc-modified-id="Revisando-el-score-del-entrenamiento-y-de-las-predicciones.-7">Revisando el score del entrenamiento y de las predicciones.</a></span></li></ul></div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
 
files.upload()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Importamos nuestro modelo para poder entranar
from sklearn.model_selection import train_test_split
# Importamos el modelo de regresión lineal
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %% [markdown]
# ### Obteniendo el dataset

# %%
dataset = pd.read_csv("salarios.csv")
dataset.head(5)
# Out:
#    Aexperiencia  Salario
# 0          10.0    42500
# 1           8.0    36302
# 2           5.4    35000
# 3           2.5    18103
# 4           1.0    15000

# %% [markdown]
# ### Separando las columnas en variables

# %%
x = dataset.iloc[: , :-1].values
y = dataset.iloc[: , 1].values
print(x,y)
# Out:
# [[10. ]
#  [ 8. ]
#  [ 5.4]
#  [ 2.5]
#  [ 1. ]
#  [ 8. ]
#  [ 4. ]
#  [ 6. ]
#  [ 2. ]
#  [10. ]
#  [ 4. ]
#  [ 7. ]
#  [ 3. ]
#  [ 5. ]
#  [ 2. ]
#  [ 5. ]
#  [ 3. ]
#  [ 2. ]
#  [ 3. ]
#  [ 2. ]
#  [ 5. ]
#  [ 3.4]
#  [ 5.3]
#  [ 2.1]
#  [ 9.2]
#  [10. ]
#  [ 3.2]
#  [10. ]
#  [ 4. ]
#  [ 1. ]] [42500 36302 35000 18103 15000 37000 26300 35201 18302 42000 27000 35201
#  19201 28000 17000 33402 19000 18200 19000 17301 28000 20000 27900 17500
#  40000 42500 18300 40000 25000 15000]

# %% [markdown]
# ### Dividimos los datos de entrenamiento y de testeo

# %%
# El test_size destina el 20% a testeo y el 80% a entrenamientp
# El random_state nos dice si vamos a modificar los datos intercambiando los de prueba y entrenamiento
X_train, X_test, Y_train, Y_test = train_test_split(x , y, test_size =  0.2, random_state = 0)

# %% [markdown]
# ### Llamamos al modelo

# %%
regression = LinearRegression()

# %% [markdown]
# ### Entrenamos

# %%
regression.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Visualizamos

# %%
# Le decimos que es un objeto con los que trabaja mat plot
visual_train = plt
# Hacemos la gráfica de los datos
visual_train.scatter(X_train, Y_train, color = '#7820D6')
# Le decimos que trace una línea con los datos de entrenamiento y la predicción del modelo de color negro
visual_train.plot(X_train, regression.predict(X_train), color ='black')
# Le agregamos su información a la gráfica
visual_train.title('Entrenamiento del modelo')
visual_train.xlabel('Experiencia')
visual_train.ylabel('Salario')
visual_train.show()

# %%
# Le decimos que es un objeto con los que trabaja mat plot
visual_train = plt
# Hacemos la gráfica de los datos
visual_train.scatter(X_test, Y_test, color = '#EE80FF')
# Le decimos que trace una línea con los datos de entrenamiento y la predicción del modelo de color negro
visual_train.plot(X_train, regression.predict(X_train), color ='black')
# Le agregamos su información a la gráfica
visual_train.title('Validación del modelo')
visual_train.xlabel('Experiencia')
visual_train.ylabel('Salario')
visual_train.show()

# %% [markdown]
# ### Revisando el score del entrenamiento y de las predicciones.

# %%
regression.score(X_train, Y_train)
# Out:
# 0.9565839912115904

# %%
regression.score(X_test, Y_test)
# Out:
# 0.7862437374732997

# %% [markdown]
# Tenemos algo de sobre ajuste.

# %% [markdown]
# ---
